# %%
# %load_ext autoreload

# %matplotlib inline
# %autoreload 2

# Supress nosiy deprecation warning from inside matplotlib
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import scipy.misc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import otsu

def plot_inout(input_image, output_image):
    fig = plt.figure(figsize=(15, 15))
    
    input = fig.add_subplot(221)
    input.imshow(input_image)
    input_hist = fig.add_subplot(223)
    input_hist.hist(input_image.flatten(), bins=256, range=(0, 256), normed=True)
    
    output = fig.add_subplot(222)
    output.imshow(output_image, )
    output_hist = fig.add_subplot(224)
    output_hist.hist(output_image.flatten(), bins=256, range=(0, 256), normed=True)
    
    fig.show()

def test_example():
    p = 'bie_threshold.jpeg'
    img = scipy.misc.imread(p)
    binary = otsu.threshold(img)
    plot_inout(img, binary)
    return None
    
test_example()
# Out:
# [   10    38     0    51    45     0    58     0    84    86     0   108
#      0   141   160     0   137   139     0   136     0   120   138     0
#    133     0   115   113     0   119   113     0   129     0   107   112
#      0   114     0   134    93     0   105     0   101   106     0    91
#     81     0    94     0    89    77     0    81     0    87    83     0
#     77    78     0    80     0    78    90     0    74     0    68    68
#      0    85     0    88    81     0    77    89     0    89     0    75
#     98     0    65     0    64    86     0   100    85     0    85     0
#     86   112     0    85     0    92   120     0    99   115     0   101
#      0   105    93     0    91     0    95   104     0    80     0   116
#    104     0    85   118     0   109     0   110   110     0    97     0
#    112   107     0   115   118     0   132     0   146   131     0   137
#      0   128   141     0   133     0   157   177     0   141   168     0
#    180     0   180   194     0   178     0   165   183     0   188   223
#      0   248     0   292   277     0   306     0   340   335     0   372
#    423     0   584     0  1230  4974     0  7514     0  4449  4462     0
#   4791     0  6312  8468     0  7849  9482     0  9834     0  9599 12186
#      0 11495     0 13291 14721     0 13373 10093     0  9374     0  7806
#   9690     0  4991     0  4984  5849     0  6839     0  5562  5415     0
#   5211  5011     0  5360     0  6278  9623     0  9380     0  9151  8196
#      0  8359 10254     0  9130     0  8839  8634     0  5493     0  5759
#   3090     0   366     2]
